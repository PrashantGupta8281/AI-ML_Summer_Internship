# %%
import pandas as pd

# %%
df = pd.read_csv("/content/AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park   2787.0
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0             1.0                9.0  2018-10-19
# 1  Entire home/apt  225.0             1.0               45.0  2019-05-21
# 2     Private room  150.0             3.0                0.0         NaN
# 3  Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4  Entire home/apt   80.0            10.0                9.0  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                             6.0             365.0
# 1               0.38                             2.0             355.0
# 2                NaN                             1.0             365.0
# 3               4.64                             1.0             194.0
# 4               0.10                             1.0               0.0

# %%
df.price.describe()
# Out:
# count    43426.000000
# mean       149.571777
# std        237.780407
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_thresold]
# Out:
#              id                                            name      host_id  \
# 957      375249                 Enjoy Staten Island Hospitality    1887999.0
# 2675    1428154             Central, Peaceful Semi-Private Room    5912572.0
# 2860    1620248   Large furnished 2 bedrooms- - 30 days Minimum    2196224.0
# 3020    1767037              Small Cozy Room Wifi & AC near JFK    9284163.0
# 3918    2431607                   Bright, Airy Room Share for 2    4973668.0
# ...         ...                                             ...          ...
# 43053  33422954                                 Spacious Studio  251781156.0
# 43071  33429492  FEMALE SHARED ROOM 3 Single Beds Near Subway-1  172369331.0
# 43374  33618303     The Pineapple tree (Girls shared room only)   51596474.0
# 43394  33632933         Comfy and quiet bed for women travelers     224150.0
# 43409  33638326             Hustler's Paradise 2 (Semi Private)  104927746.0
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# 957    Rimma & Jim       Staten Island        Graniteville  40.62109
# 2675       Tangier            Brooklyn            Flatbush  40.63899
# 2860         Sally           Manhattan        East Village  40.73051
# 3020       Antonio              Queens           Woodhaven  40.68968
# 3918        Gloria            Brooklyn  Bedford-Stuyvesant  40.68642
# ...            ...                 ...                 ...       ...
# 43053      Trinize               Bronx             Tremont  40.84581
# 43071         Abby            Brooklyn        Coney Island  40.57776
# 43374       Antony            Brooklyn           Gravesend  40.58649
# 43394     Svetlana            Brooklyn             Midwood  40.61489
# 43409     Amardeep       Staten Island             Concord  40.59700
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 957    -74.16534     Private room   20.0             3.0               80.0
# 2675   -73.95177      Shared room   29.0             2.0                5.0
# 2860   -73.98140  Entire home/apt   10.0            30.0                0.0
# 3020   -73.85219     Private room   29.0             2.0              386.0
# 3918   -73.93440      Shared room   25.0             5.0               76.0
# ...          ...              ...    ...             ...                ...
# 43053  -73.88890      Shared room   25.0             2.0                5.0
# 43071  -73.98313      Shared room   25.0             3.0                2.0
# 43374  -73.97339      Shared room   24.0            11.0                2.0
# 43394  -73.94541      Shared room   26.0             2.0                5.0
# 43409  -74.08778      Shared room   29.0             1.0                0.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 957    2019-05-26               0.92                             1.0
# 2675   2014-10-20               0.07                             1.0
# 2860          NaN                NaN                             4.0
# 3020   2019-06-19               5.53                             3.0
# 3918   2019-06-06               1.22                             3.0
# ...           ...                ...                             ...
# 43053  2019-07-01               1.60                             1.0
# 43071  2019-06-11               1.05                            10.0
# 43374  2019-05-02               0.74                            12.0
# 43394  2019-05-10               1.83                             1.0
# 43409         NaN                NaN                             7.0
#
#        availability_365
# 957               226.0
# 2675              321.0
# 2860              137.0
# 3020               50.0
# 3918              258.0
# ...                 ...
# 43053             146.0
# 43071               0.0
# 43374               0.0
# 43394               0.0
# 43409               2.0
#
# [334 rows x 16 columns]

# %%
df2 = df[(df.price>min_thresold)&(df.price<max_thresold)]
df2.shape
# Out:
# (42823, 16)

# %%
df2.sample(5)
# Out:
#              id                                              name  \
# 41083  31950082    Large Remodeled Home in Red Hook, Brooklyn, NY
# 486      169483  Very close to Downtown Awesome Private Apartment
# 25544  20440400                              East Village Getaway
# 19229  15310116                     Sunny  Space in Crown Heights
# 27438  21630372                    Beautiful and confortable room
#
#            host_id  host_name neighbourhood_group    neighbourhood  latitude  \
# 41083    6902218.0  Christele            Brooklyn         Red Hook  40.67697
# 486       807642.0    Jeffrey            Brooklyn        Gravesend  40.60452
# 25544   42701042.0       Nick           Manhattan     East Village  40.72698
# 19229   77778146.0      Andre            Brooklyn    Crown Heights  40.66631
# 27438  109146538.0    Marisol              Queens  Jackson Heights  40.75184
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 41083  -74.00993  Entire home/apt  250.0             3.0                0.0
# 486    -73.97103  Entire home/apt  106.0             7.0                0.0
# 25544  -73.98948  Entire home/apt  181.0             1.0                0.0
# 19229  -73.94764     Private room   95.0            30.0                3.0
# 27438  -73.88722     Private room   60.0             1.0               46.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 41083         NaN                NaN                             1.0
# 486           NaN                NaN                             2.0
# 25544         NaN                NaN                             1.0
# 19229  2018-09-03               0.15                             8.0
# 27438  2019-07-01               2.29                             1.0
#
#        availability_365
# 41083               1.0
# 486                 0.0
# 25544               0.0
# 19229             189.0
# 27438              30.0

# %%
df2.price.describe()
# Out:
# count    42823.000000
# mean       145.545431
# std        149.941418
# min         31.000000
# 25%         70.000000
# 50%        106.000000
# 75%        175.000000
# max       2999.000000
# Name: price, dtype: float64
